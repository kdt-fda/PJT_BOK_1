# %%
import requests
from bs4 import BeautifulSoup

# %%
page = 1
base_url = f'https://www.donga.com/news/search?p={page-1}1&query=%ED%95%9C%EA%B5%AD%EC%9D%80%ED%96%89+%EA%B8%88%EB%A6%AC&check_news=91&sorting=2&search_date=5&v1=20150101&v2=20241231&more=1'

# %%
headers = {
    'User-Agent': 'Mozilla/5.0'
}

res = requests.get(base_url, headers=headers)

res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
data = soup.find_all('h4')
data
# Out:
# [<h4 class="tit"><a data-ep_button_area="검색결과" data-ep_button_category="검색" data-ep_button_name="이주열 “물가위주 통화정책 바람직 안해”" data-ep_contentdata_content_id="68864096" data-ep_contentdata_content_title="이주열 “물가위주 통화정책 바람직 안해”" data-event_name="click_event" href="https://www.donga.com/news/article/all/20141231/68864096/1">이주열 “물가위주 통화정책 바람직 안해”</a></h4>,
#  <h4 class="tit"><a data-ep_button_area="검색결과" data-ep_button_category="검색" data-ep_button_name="“美-中 주식-펀드 투자 유망… 강남권 재건축 노려볼만”" data-ep_contentdata_content_id="68864234" data-ep_contentdata_content_title="“美-中 주식-펀드 투자 유망… 강남권 재건축 노려볼만”" data-event_name="click_event" href="https://www.donga.com/news/article/all/20141231/68864234/1">“美-中 주식-펀드 투자 유망… 강남권 재건축 노려볼만”</a></h4>,
# ...

# %%
actual_url = data[0].find('a')['href']

# %%
res = requests.get(actual_url)

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
# Out:
# [<section class="news_view">
#  <figure class="img_cont articlePhotoR" style="max-width:160px;">
#  <div class="in_cont">
#  <img alt="" src="https://dimg.donga.com/wps/NEWS/IMAGE/2014/12/31/68864075.1.jpg"/>
#  </div>
# ...

# %%
docs = []

# %%
# 날짜
date = soup.find_all('span', {'aria-hidden': 'true'})[0].text
date
# Out:
# '2015-01-01 09:58'

# %%
# 제목
title = soup.find_all('h1')[0].text
title
# Out:
# '이주열 “물가위주 통화정책 바람직 안해”'

# %%
# 본문
html = soup.find_all('section', {'class': 'news_view'})

article_element = html[0]

for tag in article_element.find_all(['figure', 'div', 'script']):
    tag.decompose()

content = article_element.get_text(strip=True)
content
# Out:
# '이주열 한국은행 총재(사진)는 새해에도 통화정책의 완화 기조를 계속 이어 가겠다고 밝혔다.이 총재는 지난해 12월 31일 발표한 신년사에서 “통화정책은 물가 안정 기조에서 성장세 회복을 지원하되 금융 안정에도 유의하며 운영해야 한다”며 “앞으로 상당 기간 국내 경제의 회복세가 완만한 가운데 낮은 물가상승률이 전망되므로 통화정책의 완화 기조를 유지할 것”이라고 말했다.다만 이 총재는 “낮은 물가상승률이 국제유가 및 농산물 가격 하락 등 공급 요인에 주로 기인하는 상황에서 통화정책을 물가 목표 달성만을 위해 운영하는 것은 바람직하지 않을 수 있다”고 덧붙였다. 물가상승률을 올리기 위해 무리하게 금리를 낮추지는 않겠다는 뜻으로 풀이된다. 그는 이어 “올해는 내년 이후에 적용할 물가 안정 목표를 설정해야 한다”며 “우리 경제의 안정적 성장을 뒷받침할 수 있는 적정 인플레이션 수준을 모색할 것”이라고 밝혔다.유재동 기자 jarrett@donga.com'

# %%
soup.find_all('span', {'aria-hidden': 'true'})[0].text
# Out:
# '2015-01-01 09:58'

# %%
data[0].find('a')['href']
# Out:
# 'https://www.donga.com/news/article/all/20141231/68864096/1'

# %%
data[1].find('a')['href']
# Out:
# 'https://www.donga.com/news/article/all/20141231/68864234/1'

# %%
for i in range(len(data)):
    actual_url = data[i].find('a')['href']

    res = requests.get(actual_url)
